# %% [markdown]
# ### Explore adding positions to player_game_stats files

# %%
import pandas as pd
import json

# %%
file_2021 = open('wnba_betting_data/2021/player_game_stats_2021.csv')

# %%
df_2021 = pd.read_csv(file_2021)
df_2021
# Out:
#                                    game_id             game_date  \
# 0     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86  2021-05-14T23:00:00Z
# 1     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86  2021-05-14T23:00:00Z
# 2     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86  2021-05-14T23:00:00Z
# 3     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86  2021-05-14T23:00:00Z
# 4     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86  2021-05-14T23:00:00Z
# ...                                    ...                   ...
# 4510  8c3e2280-0bde-4ff4-9c24-4c056386260b  2021-09-19T22:00:00Z
# 4511  8c3e2280-0bde-4ff4-9c24-4c056386260b  2021-09-19T22:00:00Z
# 4512  8c3e2280-0bde-4ff4-9c24-4c056386260b  2021-09-19T22:00:00Z
# 4513  8c3e2280-0bde-4ff4-9c24-4c056386260b  2021-09-19T22:00:00Z
# 4514  8c3e2280-0bde-4ff4-9c24-4c056386260b  2021-09-19T22:00:00Z
#
#                                  player_id         player_name     team  \
# 0     6af7f9f6-8d43-4d92-b7c5-d856f4649333       Jazmine Jones  Liberty
# 1     4d70f9da-972d-4903-b9e5-d4d4aaa0a91d  Michaela Onyenwere  Liberty
# 2     bf6cc2e8-24a2-4681-9091-786fca8f539a  Jocelyn Willoughby  Liberty
# 3     2199ae2c-7588-4610-9deb-a1b5e8025d43     Sabrina Ionescu  Liberty
# 4     111c118b-ba4d-4a6e-b449-f858bee28b5e       DiDi Richards  Liberty
# ...                                    ...                 ...      ...
# 4510  694de0b2-2e26-4778-ae03-43d38d915637     Jantel Lavender    Fever
# 4511  91af985a-7a67-42c0-8888-6a5e3e0a30e4      Aaliyah Wilson    Fever
# 4512  5219e39b-9341-4dfb-a43c-793723729162     Kelsey Mitchell    Fever
# 4513  100f94c5-3a62-4300-98bb-fe587522c2a6    Tiffany Mitchell    Fever
# 4514  1cca5ba9-8ddb-4029-969a-a5768993a0dd         Emma Cannon    Fever
#
#      opponent home_away  starter minutes  three_points_made  three_points_att  \
# 0       Fever      home    False   14:22                  0                 1
# 1       Fever      home     True   28:42                  3                 6
# 2       Fever      home    False   00:00                  0                 0
# 3       Fever      home     True   36:55                  4                 8
# 4       Fever      home    False    8:39                  0                 0
# ...       ...       ...      ...     ...                ...               ...
# 4510      Sky      away    False   22:06                  1                 3
# 4511      Sky      away    False   00:00                  0                 0
# 4512      Sky      away     True   37:48                  4                 7
# 4513      Sky      away    False   00:00                  0                 0
# 4514      Sky      away     True   34:42                  1                 2
#
#       points
# 0          0
# 1         18
# 2          0
# 3         25
# 4          2
# ...      ...
# 4510       7
# 4511       0
# 4512      32
# 4513       0
# 4514      19
#
# [4515 rows x 12 columns]

# %%
filtered_df_2021 = df_2021[['game_id', 'player_id', 'home_away']]
filtered_df_2021
# Out:
#                                    game_id  \
# 0     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86
# 1     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86
# 2     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86
# 3     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86
# 4     fa563e76-0e3b-4d94-a9e7-862bd5e8aa86
# ...                                    ...
# 4510  8c3e2280-0bde-4ff4-9c24-4c056386260b
# 4511  8c3e2280-0bde-4ff4-9c24-4c056386260b
# 4512  8c3e2280-0bde-4ff4-9c24-4c056386260b
# 4513  8c3e2280-0bde-4ff4-9c24-4c056386260b
# 4514  8c3e2280-0bde-4ff4-9c24-4c056386260b
#
#                                  player_id home_away
# 0     6af7f9f6-8d43-4d92-b7c5-d856f4649333      home
# 1     4d70f9da-972d-4903-b9e5-d4d4aaa0a91d      home
# 2     bf6cc2e8-24a2-4681-9091-786fca8f539a      home
# 3     2199ae2c-7588-4610-9deb-a1b5e8025d43      home
# 4     111c118b-ba4d-4a6e-b449-f858bee28b5e      home
# ...                                    ...       ...
# 4510  694de0b2-2e26-4778-ae03-43d38d915637      away
# 4511  91af985a-7a67-42c0-8888-6a5e3e0a30e4      away
# 4512  5219e39b-9341-4dfb-a43c-793723729162      away
# 4513  100f94c5-3a62-4300-98bb-fe587522c2a6      away
# 4514  1cca5ba9-8ddb-4029-969a-a5768993a0dd      away
#
# [4515 rows x 3 columns]

# %%
# for game_id in filtered_df_2021['game_id']:
#     open(f'wnba_betting_data/2021/game_{game_id}.json')

for index, row in filtered_df_2021.iterrows():
    print(row)

# %%
with open('wnba_betting_data/2021/game_fa563e76-0e3b-4d94-a9e7-862bd5e8aa86.json') as f:
    data = json.load(f)


json_test_df = pd.json_normalize(data)
json_test_df.columns.to_list()

# %%
# to later do some data analysis to combine positions to the player_game_stats
with open('wnba_betting_data/2021/game_fa563e76-0e3b-4d94-a9e7-862bd5e8aa86.json') as f:
    data = json.load(f)
home_players_df = pd.json_normalize(data, record_path=['home', 'players'])
home_players_df_selection = home_players_df[['full_name', 'id', 'position']] 
# home_players_df_selection
player_id = "6af7f9f6-8d43-4d92-b7c5-d856f4649333"
position = home_players_df.query(f"id == '{player_id}'")["position"][0]
position
# Out:
# 'G'

# %%
# To later extract statistics of each player from a game to train an ml model
player_statistics_extraction_df = pd.json_normalize(data, record_path=['home', 'players'])
player_id = 'bf6cc2e8-24a2-4681-9091-786fca8f539a'
player_statistics_extraction_df.query(f"id == '{player_id}'").filter(["id", "position"])
player_statistics_extraction_df.query(f"id == '{player_id}'")["position"].iloc[0]
# Out:
# 'F-G'

# %%
# Expirement
# df = pd.read_csv('wnba_betting_data/2021/player_game_stats_2021.csv')
# l = [{"name": "e"}]
# l.append({"name": "f"})
# l[1]["name"]
        
rand_list = [1, 2]
print(f"length: {len(rand_list)}, final index: {rand_list[len(rand_list) - 1]}")
# Out:
# length: 2, final index: 2

# %% [markdown]
# # Make script to automate adding the positions

# %%
import pandas as pd
import json

# %%
# Revised script for better efficiency, each run will work for one year, so that the output can be more easily managed
# poor readability cos edge case logic, but much better functioning than before
years = [2021, 2022, 2023, 2024]

for year in years:
    filtered_list = [] # -> List of dictionaries to store necessary values of DF 

    # Collect all games and their participants within a season
    with open(f"wnba_betting_data/{year}/player_game_stats_{year}.csv") as f:
        original_df = pd.read_csv(f)
        for index, row in original_df.iterrows():
            temp_dict = {"game_id": row["game_id"], "player_id": row["player_id"], "home_away": row["home_away"]}
            filtered_list.append(temp_dict)

    game_id = None if not filtered_list else filtered_list[0]["game_id"]
    game_batch = []
    final_form = []
        
    for i in range(len(filtered_list)):
        
        if i == (len(filtered_list) - 1):
            game_batch.append(filtered_list[i])
            game_id = "Activate Processing" # To handle edge case for last game (1)

        if game_id != filtered_list[i]["game_id"]:
            if i == (len(filtered_list) - 1): # To handle edge case for last game (2)
                game_id = filtered_list[i]['game_id'] 

            with open(f"wnba_betting_data/{year}/game_{game_id}.json") as f:
                data = json.load(f)
                temp_df_home = pd.json_normalize(data, record_path=["home", "players"])
                temp_df_away = pd.json_normalize(data, record_path=["away", "players"])
                for row in game_batch:
                    player_id = row["player_id"]
                    if row["home_away"] == "home":
                        position_element = temp_df_home.query(f"id == '{player_id}'")["position"].iloc[0]
                        temp_dict = {"game_id": game_id, "player_id": player_id, "home_away": row["home_away"], "position": position_element}
                        final_form.append(temp_dict)
                    elif row["home_away"] == "away":
                        position_element = temp_df_away.query(f"id == '{player_id}'")["position"].iloc[0]
                        temp_dict = {"game_id": game_id, "player_id": player_id, "home_away": row["home_away"], "position": position_element}
                        final_form.append(temp_dict)
                    
            game_id = filtered_list[i]["game_id"]
            game_batch.clear()
            game_batch.append(filtered_list[i]) # append this row or else it will be skipped

        else:
            game_batch.append(filtered_list[i]) 

    final_form = pd.DataFrame(final_form)

    player_game_stats_positions = pd.concat([original_df, final_form.filter(items=["position"])], axis=1)
    player_game_stats_positions.to_csv(f"wnba_betting_data/{year}/player_game_stats_positions_{year}.csv", index=False)

# %%
# Test to confirm all the rows have been kept in the same order

# original_df["game_id"].equals(final_form["game_id"])
# original_df["player_id"].equals(final_form["player_id"])
# original_df["home_away"].equals(final_form["home_away"])
# Out:
# True
